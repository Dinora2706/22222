# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = {"15-18":200, "19-24":80, "25 or above":50, "10-14":50}
courses = list(data.keys())
values = list(data.values())
fig = plt.figure(figsize = (5, 5))


plt.bar(courses, values, color = "blue", width = 0.4)
plt.xlabel("market segment", fontsize =18, color = "black")
plt.ylabel("Expected number of customers", fontsize = 16, color = "black")
plt.title("Сustomer potential by market segment", color = "black")
plt.xticks(rotation = 90)
plt.ticklabel_format(style = "plain")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# D:\anacond\lib\site-packages\matplotlib\axes\_base.py in ticklabel_format(self, axis, style, scilimits, useOffset, useLocale, useMathText)
#    2955                 if is_sci_style is not None:
# -> 2956                     axis.major.formatter.set_scientific(is_sci_style)
#    2957                 if scilimits is not None:
#
# AttributeError: 'StrCategoryFormatter' object has no attribute 'set_scientific'
#
# The above exception was the direct cause of the following exception:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-87a8727a56d0> in <module>
#      10 plt.title("Сustomer potential by market segment", color = "black")
#      11 plt.xticks(rotation = 90)
# ---> 12 plt.ticklabel_format(style = "plain")
#      13
#      14 plt.show()
#
# ...
